# %% [markdown]
# ## Optional HW6: Scatterplot Matrix

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(197)
numvars, numdata = 4, 10
data = pd.DataFrame(10 * np.random.random((numvars, numdata)), index=['mpg', 'disp', 'drat', 'wt']).T
data
# Out:
#         mpg      disp      drat        wt
# 0  8.679068  3.908245  9.186586  0.288368
# 1  7.847029  7.672492  4.607231  8.420929
# 2  9.762618  1.711024  9.885268  7.822549
# 3  7.687491  5.360599  2.827168  1.743799
# 4  7.355216  2.226544  1.877714  1.590668
# 5  2.770028  7.032882  0.535049  7.266437
# 6  7.347605  5.295628  0.779812  4.338848
# 7  7.031338  5.214962  6.755344  7.603964
# 8  2.825170  5.315331  6.071137  8.384394
# 9  5.810136  6.552197  3.433785  6.093847

# %% [markdown]
# ### Prob 1
# #### Create a function `scatterplot_matrix` that generates a scatter plot matrix from the above data set as below
#
# ```python
# %matplotlib inline
# fig = scatterplot_matrix(data,
#             linestyle='none', marker='o', color='black', mfc='none')
# fig.suptitle('Simple Scatterplot Matrix')
# plt.show()```
#
# <div>
# <img src="https://i.stack.imgur.com/Sz6SK.jpg" width="700"/>
# </div>

# %% [markdown]
# ### Prob 2
# #### Do the above in `seaborn` (don't worry about the diagonal subplots) . Example:
#
# ```python
# import seaborn as sns
# sns.set(style="ticks")
#
# df = sns.load_dataset("iris")
# sns.pairplot(df, hue="species")
# ```
